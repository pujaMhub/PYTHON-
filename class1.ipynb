# %% [markdown]
# <a href="https://colab.research.google.com/github/pujaMhub/PYTHON-/blob/main/class1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print('python hello world')
# Out:
# python hello world

# %%
print(salman khan)
# Out:
#   File "/tmp/ipykernel_8819/1115953987.py", line 1
#     print(salman khan)
#           ^
# SyntaxError: invalid syntax. Perhaps you forgot a comma?

# %%
print('salman khan')
# Out:
# salman khan

# %%
print(7.7)
# Out:
# 7.7

# %%
print(True)
# Out:
# True

# %%
print('hello',1,4.5,False)
# Out:
# hello 1 4.5 False

# %%
print('hello',1,4.5,False,sep='/')
# Out:
# hello/1/4.5/False

# %%
print('heloo',end='/')
print('rttt')
# Out:
# heloo/rttt

# %%
print(1e308)
# Out:
# 1e+308

# %%
print(type([1,2,3]))
# Out:
# <class 'list'>

# %%
fname=input("enter first name:")
sname=input("enter second name:")
r=int(fname)+int(sname)
print(r)
# Out:
# enter first name:56
# enter second name:65
# 121

# %%
print(9+10.9)
print(9+'9')
# Out:
# 19.9
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_1719/2233412670.py in <cell line: 0>()
#       1 print(9+10.9)
# ----> 2 print(9+'9')
#
# TypeError: unsupported operand type(s) for +: 'int' and 'str'

# %%
print(int('9'))
print(type(int('9')))
int('4')
int(4+5j)
# Out:
# 9
# <class 'int'>
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_1719/560970031.py in <cell line: 0>()
#       2 print(type(int('9')))
#       3 int('4')
# ----> 4 int(4+5j)
#
# TypeError: int() argument must be a string, a bytes-like object or a real number, not 'complex'

# %%
str(5)
float(5)
# Out:
# 5.0
